# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
shootingsplits = pd.read_csv("Datasets/Shooting Splits.csv")
shootingsplits
# Out:
#      YEAR  TEAM NO  TEAM ID           TEAM  CONF  DUNKS FG%  DUNKS SHARE  \
# 0    2024     1079        2          Akron   MAC       97.2          6.8
# 1    2024     1078        3        Alabama   SEC       81.9          9.5
# 2    2024     1077        8        Arizona   P12       91.2         11.9
# 3    2024     1076       12         Auburn   SEC       87.7         13.2
# 4    2024     1075       14         Baylor   B12       89.2         11.6
# ..    ...      ...      ...            ...   ...        ...          ...
# 944  2010      135      235  West Virginia    BE       95.0          2.8
# 945  2010      134      239       Winthrop  BSth       87.1          2.3
# 946  2010      133      240      Wisconsin   B10       93.0          4.1
# 947  2010      132      241        Wofford    SC       78.9          1.5
# 948  2010      131      244         Xavier   A10       90.4          6.6
#
#      DUNKS FG%D  DUNKS D SHARE  CLOSE TWOS FG%  ...  CLOSE TWOS FG%D RANK  \
# ...

# %%
kpbar = pd.read_csv("Datasets/KenPom Barttorvik.csv")
kpbar
# Out:
#       YEAR  CONF  CONF ID  QUAD NO  QUAD ID  TEAM NO  TEAM ID  \
# 0     2024   MAC       17       61        1     1079        2
# 1     2024   SEC       28       63        3     1078        3
# 2     2024   P12       24       63        3     1077        8
# 3     2024   SEC       28       64        4     1076       12
# 4     2024   B12        7       63        3     1075       14
# ...    ...   ...      ...      ...      ...      ...      ...
# 1074  2008    BE        8        1        1        5      235
# 1075  2008    SB       26        1        1        4      236
# 1076  2008  BSth       10        4        4        3      239
# 1077  2008   B10        6        3        3        2      240
# 1078  2008   A10        1        1        1        1      244
#
#                   TEAM  SEED  ROUND  ...  BADJT RANK  AVG HGT RANK  \
# 0                Akron    14      0  ...         276           238
# 1              Alabama     4      0  ...          13            33
# ...

# %%
teamresults = pd.read_csv("Datasets/Team Results.csv")
teamresults
# Out:
#      TEAM ID               TEAM  PAKE  PAKE RANK  PASE  PASE RANK  GAMES   W  \
# 0          1  Abilene Christian   0.7         45   0.7         52      3   1
# 1          2              Akron  -0.9        179  -1.1        187      4   0
# 2          3            Alabama  -2.1        211  -2.9        220     10   5
# 3          4             Albany  -0.4        147  -0.3        138      3   0
# 4          6           American  -0.5        160  -0.4        150      3   0
# ..       ...                ...   ...        ...   ...        ...    ...  ..
# 231      241            Wofford  -1.2        191  -0.9        175      6   1
# 232      242         Wright St.  -0.2        118  -0.2        119      2   0
# 233      243            Wyoming  -0.2        118  -0.5        159      1   0
# 234      244             Xavier   4.1         14   2.7         22     28  18
# 235      245               Yale  -0.1         91   0.2         71      4   1
#
# ...

# %%
heatchecktour = pd.read_csv("Datasets/Heat Check Tournament Index.csv")
heatchecktour
# Out:
#      YEAR  TEAM NO              TEAM  SEED  ROUND  POWER  PATH  DRAW  WINS  \
# 0    2024     1067       Connecticut     1      1   91.3  64.5   NaN     6
# 1    2024     1026           Stetson    16     64   47.1  91.0   NaN     0
# 2    2024     1060  Florida Atlantic     8     64   69.3  73.2   NaN     0
# 3    2024     1036      Northwestern     9     32   62.9  75.5   NaN     1
# 4    2024     1029     San Diego St.     5     16   71.5  68.2   NaN     2
# ..    ...      ...               ...   ...    ...    ...   ...   ...   ...
# 699  2013      336               VCU     5     32   70.8  73.3 -1.58     1
# 700  2013      335         Villanova     9     64   60.5  78.4 -1.20     0
# 701  2013      334  Western Kentucky    16     64   50.0  86.1  0.12     0
# 702  2013      333       Wichita St.     9      4   68.7  81.1 -2.03     4
# 703  2013      332         Wisconsin     5     64   78.6  70.9 -0.42     0
#
#      POOL VALUE  POOL S-RANK  NCAA S-RANK  VAL Z-SCORE  POWER-PATH
# ...

# %%
heatchecktour.dropna()
# Out:
#      YEAR  TEAM NO              TEAM  SEED  ROUND  POWER  PATH  DRAW  WINS  \
# 64   2023     1011           Alabama     1     16   85.2  63.8  1.51     2
# 65   2023     1010           Arizona     2     64   80.9  65.3  0.65     0
# 66   2023     1009       Arizona St.    11     64   60.2  75.2 -0.27     0
# 67   2023     1008          Arkansas     8     16   78.1  75.6 -0.60     2
# 68   2023     1007            Auburn     9     32   71.9  72.7  0.54     1
# ..    ...      ...               ...   ...    ...    ...   ...   ...   ...
# 699  2013      336               VCU     5     32   70.8  73.3 -1.58     1
# 700  2013      335         Villanova     9     64   60.5  78.4 -1.20     0
# 701  2013      334  Western Kentucky    16     64   50.0  86.1  0.12     0
# 702  2013      333       Wichita St.     9      4   68.7  81.1 -2.03     4
# 703  2013      332         Wisconsin     5     64   78.6  70.9 -0.42     0
#
#      POOL VALUE  POOL S-RANK  NCAA S-RANK  VAL Z-SCORE  POWER-PATH
# ...

# %%
sshct = pd.merge(shootingsplits,heatchecktour)
sshct
sshct.to_csv('ShootingSplits_HeatCheckTour.csv')

# %%
sshct
# Out:
#      YEAR  TEAM NO  TEAM ID              TEAM CONF  DUNKS FG%  DUNKS SHARE  \
# 0    2024     1079        2             Akron  MAC       97.2          6.8
# 1    2024     1078        3           Alabama  SEC       81.9          9.5
# 2    2024     1077        8           Arizona  P12       91.2         11.9
# 3    2024     1076       12            Auburn  SEC       87.7         13.2
# 4    2024     1075       14            Baylor  B12       89.2         11.6
# ..    ...      ...      ...               ...  ...        ...          ...
# 699  2013      336      226               VCU  A10       88.0          5.2
# 700  2013      335      228         Villanova   BE       74.6          6.1
# 701  2013      334      236  Western Kentucky   SB       88.2          4.2
# 702  2013      333      238       Wichita St.  MVC       86.8          4.9
# 703  2013      332      240         Wisconsin  B10       86.7          6.4
#
# ...

# %%
tourmatch = pd.read_csv("Datasets/Tournament Matchups.csv")
tourmatch
# Out:
#       YEAR  BY YEAR NO  BY ROUND NO  TEAM NO            TEAM  SEED  ROUND  \
# 0     2024        2036            0     1067     Connecticut     1      1
# 1     2024        2035            0     1026         Stetson    16     64
# 2     2024        2034            0     1038  North Carolina     1      1
# 3     2024        2033            0     1055          Howard    16     64
# 4     2024        2032            0     1038  North Carolina     1      1
# ...    ...         ...          ...      ...             ...   ...    ...
# 2031  2008           5           33       43          Kansas     1      1
# 2032  2008           4           32       37         Memphis     1      2
# 2033  2008           3           31       13            UCLA     1      4
# 2034  2008           2            2       43          Kansas     1      1
# 2035  2008           1            1       37         Memphis     1      2
#
#       CURRENT ROUND  SCORE
# 0                64    NaN
# ...

# %%
tourmatch.dropna()
# Out:
#       YEAR  BY YEAR NO  BY ROUND NO  TEAM NO                    TEAM  SEED  \
# 148   2023        1888         1888     1011                 Alabama     1
# 149   2023        1887         1887      955  Texas A&M Corpus Chris    16
# 150   2023        1886         1886      979                Maryland     8
# 151   2023        1885         1885      945           West Virginia     9
# 152   2023        1884         1884      961           San Diego St.     5
# ...    ...         ...          ...      ...                     ...   ...
# 2031  2008           5           33       43                  Kansas     1
# 2032  2008           4           32       37                 Memphis     1
# 2033  2008           3           31       13                    UCLA     1
# 2034  2008           2            2       43                  Kansas     1
# 2035  2008           1            1       37                 Memphis     1
#
#       ROUND  CURRENT ROUND  SCORE
# ...
