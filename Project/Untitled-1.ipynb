# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor #new
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("Datasets/Shooting Splits.csv")
df1 = pd.read_csv("Datasets/Team Results.csv")

# %%
# Out:
#    YEAR  TEAM NO  TEAM ID     TEAM CONF  DUNKS FG%  DUNKS SHARE  DUNKS FG%D  \
# 0  2024     1079        2    Akron  MAC       97.2          6.8        90.6
# 1  2024     1078        3  Alabama  SEC       81.9          9.5        89.2
# 2  2024     1077        8  Arizona  P12       91.2         11.9        89.3
# 3  2024     1076       12   Auburn  SEC       87.7         13.2        87.1
# 4  2024     1075       14   Baylor  B12       89.2         11.6        91.8
#
#    DUNKS D SHARE  CLOSE TWOS FG%  ...  R64  R32  S16  E8  F4  F2  CHAMP  TOP2  \
# 0            5.6            62.8  ...    4    0    0   0   0   0      0     0
# 1            7.3            63.1  ...    5    3    2   0   0   0      0     2
# 2            5.9            63.3  ...   11    7    7   3   0   0      0     5
# 3            4.7            61.7  ...    4    4    1   1   1   0      0     1
# 4            7.2            65.7  ...   11    8    5   3   1   1      1     2
#
#       F4%  CHAMP%
# 0   0.50%   0.00%
# ...
