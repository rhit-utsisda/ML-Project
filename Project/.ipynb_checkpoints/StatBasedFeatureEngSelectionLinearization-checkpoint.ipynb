# %%
import pandas as pd
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.model_selection import GridSearchCV
import graphviz 
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, export_text
import graphviz  
from sklearn.tree import export_graphviz

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('ShootingSplits_HeatCheckTour.csv')
df = df.dropna(axis=1)
print(df.shape)
df.head(3)
# Out:
# (704, 47)
#    Unnamed: 0  YEAR  TEAM NO  TEAM ID     TEAM CONF  DUNKS FG%  DUNKS SHARE  \
# 0           0  2024     1079        2    Akron  MAC       97.2          6.8
# 1           1  2024     1078        3  Alabama  SEC       81.9          9.5
# 2           2  2024     1077        8  Arizona  P12       91.2         11.9
#
#    DUNKS FG%D  DUNKS D SHARE  ...  THREES D SHARE RANK  SEED  ROUND  POWER  \
# 0        90.6            5.6  ...                  170    14     64   54.3
# 1        89.2            7.3  ...                  164     4      4   77.3
# 2        89.3            5.9  ...                  219     2     16   86.2
#
#    PATH  WINS  POOL VALUE  POOL S-RANK  NCAA S-RANK  POWER-PATH
# 0  79.8     0         2.0           54           54       -25.5
# 1  66.4     4        39.0           13           16        10.9
# 2  64.6     2        91.8            2            6        21.6
#
# [3 rows x 47 columns]

# %%
df_train = df[df['YEAR'] != 2024]
df_test = df[df['YEAR'] == 2024]
X_train = df_train.drop(['Unnamed: 0','YEAR','TEAM NO','TEAM ID','TEAM','CONF','WINS','ROUND', 'POWER-PATH', 'POWER', 'PATH', 'POOL VALUE', 'POOL S-RANK', 'NCAA S-RANK'],axis=1)
X_test = df_test.drop(['Unnamed: 0','YEAR','TEAM NO','TEAM ID','TEAM','CONF','WINS','ROUND', 'POWER-PATH', 'POWER', 'PATH', 'POOL VALUE', 'POOL S-RANK', 'NCAA S-RANK'],axis=1)
stnd = StandardScaler().set_output(transform = 'pandas')
X_train = stnd.fit_transform(X_train)
X_test = stnd.transform(X_test)
y_train = df_train.WINS
y_test = df_test.WINS

# %%
poly = PolynomialFeatures(2, interaction_only = False, include_bias = False)
Xe_train = poly.fit_transform(X_train)
Xe_train = pd.DataFrame(Xe_train, columns = poly.get_feature_names_out())
Xe_test = poly.fit_transform(X_test)
Xe_test = pd.DataFrame(Xe_test, columns = poly.get_feature_names_out())
Xe_train['bias'] = 1
Xe_test['bias'] = 1

# %%
def SelectFeature(model,candidates,Xe_train,y_train):
    lr = LogisticRegression()
    R2_valid = []
    for candidate in candidates:
        model.append(candidate)
        R2_valid_scores = cross_validate(lr, Xe_train[model], y_train)['test_score']
        R2_valid.append(R2_valid_scores.mean())
        model.remove(candidate)
    print(len(candidates), max(R2_valid))
    return (candidates[R2_valid.index(max(R2_valid))], max(R2_valid))

# %%
model = ['bias']
candidates = list(Xe_train.columns)
candidates.remove('bias')

lr = LogisticRegression()
R2_valid_scores = cross_validate(lr, Xe_train[model], y_train)['test_score']
R2 = [R2_valid_scores.mean()]

while (len(candidates)):
    (x,R2_max) = SelectFeature(model,candidates,Xe_train,y_train)
    candidates.remove(x)
    model.append(x)
    R2.append(R2_max)
# Out:
# KeyboardInterrupt

# %%
results = pd.DataFrame()
results['feature added'] = model
results['valid R2'] = R2
ix = results['valid R2'].idxmax()
model_opt = model[0:ix+1]
pd.set_option('display.max_rows', 600)
display(results)
# Out:
#                                          feature added     valid R2
# 0                                                 bias     0.000000
# 1                                                 SEED     0.285587
# 2                                  CLOSE TWOS FG% SEED     0.315499
# 3                                  CLOSE TWOS FG% RANK     0.326943
# 4                                               SEED^2     0.334696
# 5                       DUNKS FG%D THREES D SHARE RANK     0.339766
# 6                          THREES SHARE DUNKS FG% RANK     0.344092
# 7                         DUNKS SHARE FARTHER TWOS FG%     0.347583
# 8                                DUNKS FG% THREES FG%D     0.350908
# 9                    CLOSE TWOS D SHARE THREES D SHARE     0.353683
# 10                  DUNKS SHARE RANK THREES SHARE RANK     0.356185
# 11                              CLOSE TWOS FG%D RANK^2     0.359174
# 12                       DUNKS FG%D CLOSE TWOS D SHARE     0.362194
# 13                    CLOSE TWOS SHARE DUNKS FG%D RANK     0.365138
# 14      CLOSE TWOS FG%D RANK FARTHER TWOS D SHARE RANK     0.368126
# 15                                    THREES FG%D RANK     0.370436
# 16                        DUNKS SHARE THREES FG%D RANK     0.372680
# 17                   THREES FG% RANK THREES SHARE RANK     0.374768
# 18                          CLOSE TWOS SHARE RANK SEED     0.376942
# 19                      DUNKS D SHARE CLOSE TWOS SHARE     0.379554
# 20                        DUNKS D SHARE CLOSE TWOS FG%     0.381843
# 21               DUNKS D SHARE CLOSE TWOS D SHARE RANK     0.383686
# 22                          DUNKS FG% CLOSE TWOS SHARE     0.385709
# 23                        FARTHER TWOS FG%D THREES FG%     0.387682
# 24                                DUNKS FG% THREES FG%     0.389826
# 25                           THREES FG% DUNKS FG% RANK     0.391249
# 26                              DUNKS FG% THREES SHARE     0.393646
# 27                   CLOSE TWOS FG% DUNKS D SHARE RANK     0.394715
# 28                    THREES FG% RANK THREES FG%D RANK     0.395945
# 29                  DUNKS D SHARE RANK THREES FG% RANK     0.397076
# 30                                   THREES SHARE SEED     0.398080
# 31                        FARTHER TWOS SHARE RANK SEED     0.399513
# 32                                       THREES FG%D^2     0.400604
# 33             DUNKS SHARE RANK FARTHER TWOS FG%D RANK     0.401284
# 34         CLOSE TWOS FG%D RANK FARTHER TWOS FG%D RANK     0.403003
# 35              CLOSE TWOS FG%D FARTHER TWOS FG%D RANK     0.404690
# 36                 DUNKS FG%D RANK CLOSE TWOS FG% RANK     0.405439
# 37                 CLOSE TWOS FG%D CLOSE TWOS FG% RANK     0.407022
# 38                             FARTHER TWOS SHARE RANK     0.407827
# 39                         DUNKS FG%D DUNKS SHARE RANK     0.408780
# 40                CLOSE TWOS SHARE THREES D SHARE RANK     0.409846
# 41                FARTHER TWOS FG% THREES D SHARE RANK     0.410897
# 42                       THREES SHARE DUNKS SHARE RANK     0.411907
# 43         FARTHER TWOS FG%D FARTHER TWOS D SHARE RANK     0.412858
# 44       CLOSE TWOS D SHARE RANK FARTHER TWOS FG% RANK     0.414304
# 45     FARTHER TWOS FG% RANK FARTHER TWOS D SHARE RANK     0.416934
# 46                  THREES D SHARE THREES D SHARE RANK     0.419617
# 47       FARTHER TWOS FG% RANK FARTHER TWOS SHARE RANK     0.420381
# 48                    FARTHER TWOS FG% THREES FG% RANK     0.421217
# 49             CLOSE TWOS SHARE FARTHER TWOS FG%D RANK     0.422016
# 50                   THREES FG%D FARTHER TWOS FG% RANK     0.422796
# 51                              DUNKS SHARE THREES FG%     0.423630
# 52                              THREES SHARE RANK SEED     0.424266
# 53                DUNKS FG% RANK CLOSE TWOS SHARE RANK     0.424853
# 54                            CLOSE TWOS FG% RANK SEED     0.425824
# 55                        THREES FG%D THREES FG%D RANK     0.426984
# 56            CLOSE TWOS FG% FARTHER TWOS D SHARE RANK     0.427708
# 57                          THREES FG%D DUNKS FG% RANK     0.428634
# 58                        THREES FG% THREES SHARE RANK     0.430053
# 59                     THREES D SHARE THREES FG%D RANK     0.430720
# 60                            DUNKS D SHARE THREES FG%     0.431280
# 61                           DUNKS SHARE DUNKS D SHARE     0.432815
# 62               DUNKS SHARE RANK CLOSE TWOS FG%D RANK     0.433387
# 63                        DUNKS FG% FARTHER TWOS SHARE     0.433917
# 64                                       DUNKS D SHARE     0.434437
# 65                                FARTHER TWOS D SHARE     0.435033
# 66                                   FARTHER TWOS FG%D     0.435835
# 67                                DUNKS FG%D RANK SEED     0.436096
# 68                     DUNKS FG%D CLOSE TWOS FG%D RANK     0.436344
# 69                          DUNKS FG%D CLOSE TWOS FG%D     0.437509
# 70             FARTHER TWOS FG% FARTHER TWOS FG%D RANK     0.437956
# 71                               THREES D SHARE RANK^2     0.438137
# 72                      FARTHER TWOS D SHARE RANK SEED     0.438245
# 73                          DUNKS FG% THREES FG%D RANK     0.438229
# 74               DUNKS FG%D RANK CLOSE TWOS SHARE RANK     0.438166
# 75             DUNKS FG%D RANK CLOSE TWOS D SHARE RANK     0.438130
# 76              DUNKS FG%D RANK FARTHER TWOS FG%D RANK     0.438448
# 77                                         DUNKS FG%^2     0.438908
# 78                       DUNKS FG% CLOSE TWOS FG% RANK     0.439307
# 79              FARTHER TWOS FG%D RANK THREES FG% RANK     0.440681
# 80                     CLOSE TWOS FG%D THREES FG% RANK     0.440900
# 81                    DUNKS D SHARE CLOSE TWOS D SHARE     0.440973
# 82                         FARTHER TWOS FG%D RANK SEED     0.440995
# 83               CLOSE TWOS FG%D CLOSE TWOS SHARE RANK     0.441109
# 84                CLOSE TWOS FG% CLOSE TWOS SHARE RANK     0.441379
# 85                   FARTHER TWOS SHARE DUNKS FG% RANK     0.441310
# 86        FARTHER TWOS FG% RANK FARTHER TWOS FG%D RANK     0.441266
# 87              FARTHER TWOS FG%D FARTHER TWOS D SHARE     0.441315
# 88                             CLOSE TWOS SHARE RANK^2     0.441404
# 89                                         THREES FG%D     0.441382
# 90                       THREES FG% DUNKS D SHARE RANK     0.441131
# 91                       DUNKS D SHARE THREES FG% RANK     0.442007
# 92                      THREES D SHARE DUNKS FG%D RANK     0.441647
# 93                                DUNKS D SHARE RANK^2     0.441340
# 94                         FARTHER TWOS FG% THREES FG%     0.441105
# 95            DUNKS D SHARE RANK CLOSE TWOS SHARE RANK     0.440910
# 96                                         DUNKS SHARE     0.440609
# 97                        CLOSE TWOS SHARE THREES FG%D     0.440328
# 98               FARTHER TWOS FG% RANK THREES FG% RANK     0.440017
# 99                      CLOSE TWOS FG%D DUNKS FG% RANK     0.439673
# 100                          DUNKS FG% DUNKS FG%D RANK     0.439485
# 101                   DUNKS SHARE RANK DUNKS FG%D RANK     0.439142
# 102                    DUNKS FG% CLOSE TWOS SHARE RANK     0.439170
# 103                   THREES FG% FARTHER TWOS FG% RANK     0.438889
# 104                        CLOSE TWOS SHARE THREES FG%     0.439045
# 105                      CLOSE TWOS D SHARE THREES FG%     0.442759
# 106                 DUNKS FG% RANK CLOSE TWOS FG% RANK     0.443481
# 107                CLOSE TWOS FG% FARTHER TWOS D SHARE     0.444423
# 108               THREES FG% FARTHER TWOS D SHARE RANK     0.444663
# 109                 DUNKS FG%D FARTHER TWOS SHARE RANK     0.444710
# 110                        CLOSE TWOS FG%D THREES FG%D     0.444861
# 111              CLOSE TWOS D SHARE DUNKS D SHARE RANK     0.444629
# 112                      DUNKS FG%D FARTHER TWOS SHARE     0.444430
# 113                      THREES D SHARE DUNKS FG% RANK     0.444040
# 114                         THREES FG% DUNKS FG%D RANK     0.443505
# 115           DUNKS D SHARE RANK FARTHER TWOS FG% RANK     0.442865
# 116                FARTHER TWOS FG% DUNKS D SHARE RANK     0.442953
# 117                  DUNKS SHARE FARTHER TWOS FG% RANK     0.442905
# 118                     DUNKS D SHARE DUNKS SHARE RANK     0.442789
# 119                        THREES FG%D DUNKS FG%D RANK     0.442912
# 120                        DUNKS FG%D THREES FG%D RANK     0.443372
# 121                    CLOSE TWOS SHARE DUNKS FG% RANK     0.443670
# 122             CLOSE TWOS SHARE FARTHER TWOS FG% RANK     0.443415
# 123                 CLOSE TWOS SHARE FARTHER TWOS FG%D     0.443069
# 124         CLOSE TWOS SHARE RANK CLOSE TWOS FG%D RANK     0.442619
# 125                                THREES D SHARE RANK     0.442294
# 126               DUNKS FG%D RANK CLOSE TWOS FG%D RANK     0.442119
# 127                THREES FG%D FARTHER TWOS SHARE RANK     0.441817
# 128                   FARTHER TWOS D SHARE THREES FG%D     0.441351
# 129                                 THREES FG%D RANK^2     0.441106
# 130                   FARTHER TWOS FG%D DUNKS FG% RANK     0.440671
# 131             FARTHER TWOS FG% RANK THREES FG%D RANK     0.439978
# 132                  THREES FG% FARTHER TWOS FG%D RANK     0.439364
# 133                        THREES FG%D THREES FG% RANK     0.439316
# 134                                 DUNKS D SHARE RANK     0.438698
# 135                          CLOSE TWOS D SHARE RANK^2     0.438166
# 136                       CLOSE TWOS D SHARE RANK SEED     0.437577
# 137                                THREES D SHARE SEED     0.437363
# 138                          DUNKS FG%D THREES D SHARE     0.436861
# 139              CLOSE TWOS FG% RANK THREES SHARE RANK     0.436274
# 140                           THREES D SHARE RANK SEED     0.435621
# 141                                    DUNKS D SHARE^2     0.434784
# 142                  CLOSE TWOS SHARE FARTHER TWOS FG%     0.434248
# 143                DUNKS FG%D RANK THREES D SHARE RANK     0.433586
# 144                THREES FG%D CLOSE TWOS D SHARE RANK     0.433854
# 145           CLOSE TWOS D SHARE RANK THREES FG%D RANK     0.433015
# 146                          THREES FG% THREES D SHARE     0.432303
# 147           CLOSE TWOS D SHARE FARTHER TWOS FG% RANK     0.431718
# 148                   CLOSE TWOS FG%D FARTHER TWOS FG%     0.431403
# 149                              DUNKS SHARE RANK SEED     0.431064
# 150                   DUNKS FG%D RANK THREES FG%D RANK     0.430626
# 151                             DUNKS FG%D THREES FG%D     0.430166
# 152                          DUNKS FG%D DUNKS FG% RANK     0.430009
# 153                  DUNKS FG% RANK DUNKS D SHARE RANK     0.429822
# 154                          FARTHER TWOS D SHARE RANK     0.429435
# 155                       DUNKS D SHARE DUNKS FG% RANK     0.428822
# 156                            CLOSE TWOS D SHARE RANK     0.427963
# 157                                     THREES D SHARE     0.428797
# 158                     DUNKS FG% CLOSE TWOS FG%D RANK     0.428153
# 159                                 FARTHER TWOS SHARE     0.427322
# 160                           THREES SHARE THREES FG%D     0.426279
# 161                 THREES SHARE RANK THREES FG%D RANK     0.425513
# 162                FARTHER TWOS SHARE THREES FG%D RANK     0.425444
# 163                   DUNKS D SHARE FARTHER TWOS SHARE     0.425104
# 164                    THREES SHARE DUNKS D SHARE RANK     0.425724
# 165                               CLOSE TWOS FG%D SEED     0.425067
# 166                     CLOSE TWOS FG% CLOSE TWOS FG%D     0.424092
# 167                                 CLOSE TWOS D SHARE     0.423109
# 168           THREES D SHARE FARTHER TWOS D SHARE RANK     0.422014
# 169         CLOSE TWOS FG% RANK FARTHER TWOS FG%D RANK     0.420848
# 170                             DUNKS SHARE DUNKS FG%D     0.419869
# 171                        DUNKS SHARE DUNKS FG%D RANK     0.419760
# 172          FARTHER TWOS D SHARE RANK THREES FG% RANK     0.418463
# 173                     CLOSE TWOS FG% THREES FG% RANK     0.417115
# 174                                    DUNKS FG%D SEED     0.415768
# 175                  DUNKS FG%D FARTHER TWOS FG%D RANK     0.415041
# 176     FARTHER TWOS SHARE RANK FARTHER TWOS FG%D RANK     0.414415
# 177      CLOSE TWOS SHARE RANK FARTHER TWOS SHARE RANK     0.413261
# 178                 CLOSE TWOS D SHARE THREES FG% RANK     0.411933
# 179                  FARTHER TWOS FG%D THREES FG% RANK     0.410750
# 180          CLOSE TWOS SHARE RANK THREES D SHARE RANK     0.409859
# 181                        DUNKS SHARE THREES FG% RANK     0.408650
# 182                  DUNKS SHARE RANK THREES FG%D RANK     0.407089
# 183                    DUNKS FG% RANK THREES FG%D RANK     0.405794
# 184           DUNKS SHARE RANK FARTHER TWOS SHARE RANK     0.404077
# 185                                  THREES FG% RANK^2     0.402354
# 186               CLOSE TWOS FG%D CLOSE TWOS FG%D RANK     0.400582
# 187               CLOSE TWOS FG% RANK THREES FG%D RANK     0.399010
# 188                                  DUNKS FG%D RANK^2     0.397291
# 189                                   DUNKS SHARE SEED     0.395558
# 190         DUNKS D SHARE RANK CLOSE TWOS D SHARE RANK     0.393603
# 191                    CLOSE TWOS FG%D DUNKS FG%D RANK     0.391496
# 192              DUNKS D SHARE FARTHER TWOS SHARE RANK     0.389381
# 193        CLOSE TWOS FG% RANK FARTHER TWOS SHARE RANK     0.387402
# 194                                 FARTHER TWOS FG%^2     0.385228
# 195        FARTHER TWOS D SHARE FARTHER TWOS FG%D RANK     0.383361
# 196         FARTHER TWOS FG% FARTHER TWOS D SHARE RANK     0.381712
# 197                    CLOSE TWOS FG% THREES FG%D RANK     0.379696
# 198         FARTHER TWOS D SHARE CLOSE TWOS SHARE RANK     0.377428
# 199              CLOSE TWOS SHARE FARTHER TWOS D SHARE     0.377916
# 200                              CLOSE TWOS SHARE RANK     0.376770
# 201                    DUNKS FG% RANK DUNKS SHARE RANK     0.374574
# 202                    THREES FG%D CLOSE TWOS FG% RANK     0.372207
# 203               CLOSE TWOS SHARE CLOSE TWOS FG% RANK     0.370289
# 204                                    THREES FG% RANK     0.368206
# 205                      DUNKS D SHARE CLOSE TWOS FG%D     0.366122
# 206                 DUNKS D SHARE CLOSE TWOS FG%D RANK     0.369113
# 207                                   FARTHER TWOS FG%     0.368816
# 208                 CLOSE TWOS FG% THREES D SHARE RANK     0.366834
# 209                    FARTHER TWOS D SHARE THREES FG%     0.364999
# 210                  FARTHER TWOS FG%D DUNKS FG%D RANK     0.363539
# 211               THREES FG%D RANK THREES D SHARE RANK     0.367309
# 212              FARTHER TWOS FG% CLOSE TWOS FG%D RANK     0.367198
# 213                    THREES D SHARE DUNKS SHARE RANK     0.365993
# 214                                    THREES FG% SEED     0.364970
# 215               DUNKS SHARE RANK THREES D SHARE RANK     0.362803
# 216                 DUNKS SHARE FARTHER TWOS FG%D RANK     0.360371
# 217                       DUNKS FG%D FARTHER TWOS FG%D     0.358116
# 218                CLOSE TWOS D SHARE FARTHER TWOS FG%     0.356811
# 219            DUNKS FG%D RANK FARTHER TWOS SHARE RANK     0.354553
# 220                         DUNKS SHARE THREES D SHARE     0.352141
# 221                DUNKS D SHARE FARTHER TWOS FG% RANK     0.349550
# 222            FARTHER TWOS SHARE CLOSE TWOS FG%D RANK     0.347303
# 223                  CLOSE TWOS FG%D FARTHER TWOS FG%D     0.344804
# 224             FARTHER TWOS FG%D CLOSE TWOS FG%D RANK     0.342709
# 225            FARTHER TWOS FG%D CLOSE TWOS SHARE RANK     0.340338
# 226                 FARTHER TWOS FG% FARTHER TWOS FG%D     0.337450
# 227            FARTHER TWOS FG%D FARTHER TWOS FG% RANK     0.334532
# 228             FARTHER TWOS FG% FARTHER TWOS FG% RANK     0.331460
# 229           DUNKS SHARE RANK CLOSE TWOS D SHARE RANK     0.328746
# 230         DUNKS SHARE RANK FARTHER TWOS D SHARE RANK     0.326463
# 231                           DUNKS FG% THREES D SHARE     0.323272
# 232         CLOSE TWOS FG%D RANK FARTHER TWOS FG% RANK     0.319892
# 233                 DUNKS D SHARE FARTHER TWOS D SHARE     0.316096
# 234            FARTHER TWOS D SHARE DUNKS D SHARE RANK     0.313936
# 235                     FARTHER TWOS SHARE THREES FG%D     0.311034
# 236  CLOSE TWOS D SHARE RANK FARTHER TWOS D SHARE RANK     0.307711
# 237              DUNKS SHARE FARTHER TWOS D SHARE RANK     0.304499
# 238                        DUNKS FG% FARTHER TWOS FG%D     0.301495
# 239             DUNKS FG% RANK FARTHER TWOS SHARE RANK     0.297842
# 240                   DUNKS FG% RANK THREES SHARE RANK     0.295651
# 241                   CLOSE TWOS FG%D DUNKS SHARE RANK     0.291505
# 242                  DUNKS FG% FARTHER TWOS SHARE RANK     0.288376
# 243            FARTHER TWOS SHARE RANK THREES FG% RANK     0.286931
# 244              DUNKS FG% RANK FARTHER TWOS FG%D RANK     0.284354
# 245             DUNKS D SHARE RANK THREES D SHARE RANK     0.281345
# 246                     DUNKS FG% RANK DUNKS FG%D RANK     0.277029
# 247                   DUNKS FG% FARTHER TWOS FG%D RANK     0.274502
# 248              FARTHER TWOS D SHARE DUNKS SHARE RANK     0.271528
# 249                                   CLOSE TWOS FG%^2     0.268323
# 250                                     DUNKS FG% RANK     0.265165
# 251                          FARTHER TWOS SHARE RANK^2     0.261624
# 252                   DUNKS FG%D FARTHER TWOS FG% RANK     0.259857
# 253                               CLOSE TWOS FG%D RANK     0.258866
# 254                  DUNKS FG%D RANK THREES SHARE RANK     0.255373
# 255                            DUNKS FG% DUNKS D SHARE     0.251570
# 256                  THREES SHARE CLOSE TWOS FG%D RANK     0.249637
# 257              CLOSE TWOS SHARE CLOSE TWOS FG%D RANK     0.246948
# 258            FARTHER TWOS FG%D RANK THREES FG%D RANK     0.242851
# 259                      FARTHER TWOS FG%D THREES FG%D     0.240242
# 260          DUNKS D SHARE RANK FARTHER TWOS FG%D RANK     0.235799
# 261                       DUNKS FG% DUNKS D SHARE RANK     0.233088
# 262                       CLOSE TWOS FG%D THREES SHARE     0.228394
# 263               FARTHER TWOS SHARE THREES SHARE RANK     0.224592
# 264               FARTHER TWOS FG%D DUNKS D SHARE RANK     0.220436
# 265                      DUNKS FG% THREES D SHARE RANK     0.216461
# 266                CLOSE TWOS FG% RANK THREES FG% RANK     0.213352
# 267                THREES SHARE FARTHER TWOS FG%D RANK     0.209921
# 268          FARTHER TWOS SHARE FARTHER TWOS FG%D RANK     0.208112
# 269                           DUNKS FG%D DUNKS D SHARE     0.204473
# 270          FARTHER TWOS SHARE RANK THREES SHARE RANK     0.202934
# 271            CLOSE TWOS D SHARE RANK THREES FG% RANK     0.199271
# 272             FARTHER TWOS D SHARE THREES SHARE RANK     0.195841
# 273             FARTHER TWOS SHARE CLOSE TWOS FG% RANK     0.191556
# 274                     CLOSE TWOS FG% DUNKS FG%D RANK     0.187668
# 275       FARTHER TWOS SHARE FARTHER TWOS D SHARE RANK     0.182785
# 276        CLOSE TWOS D SHARE RANK THREES D SHARE RANK     0.179130
# 277                    THREES FG% CLOSE TWOS FG%D RANK     0.175116
# 278            DUNKS D SHARE FARTHER TWOS D SHARE RANK     0.170670
# 279       DUNKS D SHARE RANK FARTHER TWOS D SHARE RANK     0.168307
# 280                                       DUNKS FG%D^2     0.164973
# 281                 THREES FG% CLOSE TWOS D SHARE RANK     0.160339
# 282                             FARTHER TWOS FG%D RANK     0.156983
# 283                          CLOSE TWOS FG% THREES FG%     0.154186
# 284                     DUNKS FG% RANK THREES FG% RANK     0.155945
# 285                            FARTHER TWOS FG% RANK^2     0.153077
# 286                              CLOSE TWOS SHARE SEED     0.152231
# 287                    DUNKS SHARE CLOSE TWOS FG% RANK     0.149012
# 288                  CLOSE TWOS SHARE THREES FG%D RANK     0.145140
# 289                     THREES SHARE THREES SHARE RANK     0.141203
# 290           CLOSE TWOS SHARE CLOSE TWOS D SHARE RANK     0.136750
# 291                         DUNKS FG%D THREES FG% RANK     0.130942
# 292                   THREES SHARE CLOSE TWOS FG% RANK     0.124402
# 293             THREES SHARE FARTHER TWOS D SHARE RANK     0.117966
# 294                 CLOSE TWOS SHARE THREES SHARE RANK     0.111678
# 295                                THREES SHARE RANK^2     0.107446
# 296                                  CLOSE TWOS FG%D^2     0.102407
# 297                    DUNKS FG%D FARTHER TWOS D SHARE     0.097858
# 298                     DUNKS D SHARE FARTHER TWOS FG%     0.094301
# 299                 THREES SHARE CLOSE TWOS SHARE RANK     0.088963
# 300             CLOSE TWOS SHARE RANK THREES FG%D RANK     0.083573
# 301       CLOSE TWOS FG%D RANK FARTHER TWOS SHARE RANK     0.076947
# 302                   THREES FG%D CLOSE TWOS FG%D RANK     0.070147
# 303        FARTHER TWOS D SHARE RANK THREES SHARE RANK     0.063905
# 304              CLOSE TWOS FG%D FARTHER TWOS FG% RANK     0.056871
# 305           FARTHER TWOS SHARE FARTHER TWOS FG% RANK     0.049698
# 306                       DUNKS D SHARE THREES D SHARE     0.046233
# 307                CLOSE TWOS D SHARE DUNKS SHARE RANK     0.038820
# 308                        DUNKS FG%D FARTHER TWOS FG%     0.032507
# 309                CLOSE TWOS SHARE DUNKS D SHARE RANK     0.026662
# 310            CLOSE TWOS SHARE RANK THREES SHARE RANK     0.017252
# 311                         CLOSE TWOS FG% THREES FG%D     0.008504
# 312            CLOSE TWOS FG%D FARTHER TWOS SHARE RANK    -0.001965
# 313                FARTHER TWOS SHARE DUNKS SHARE RANK    -0.011345
# 314          CLOSE TWOS FG%D FARTHER TWOS D SHARE RANK    -0.019778
# 315                 THREES FG%D FARTHER TWOS FG%D RANK    -0.028568
# 316               DUNKS SHARE RANK CLOSE TWOS FG% RANK    -0.038174
# 317                           DUNKS SHARE THREES SHARE    -0.046440
# 318                  CLOSE TWOS SHARE DUNKS SHARE RANK    -0.053745
# 319                                 DUNKS D SHARE SEED    -0.062879
# 320                FARTHER TWOS FG%D THREES SHARE RANK    -0.072362
# 321                     FARTHER TWOS FG%D THREES SHARE    -0.079062
# 322                     DUNKS FG% FARTHER TWOS D SHARE    -0.092351
# 323                       DUNKS FG% CLOSE TWOS D SHARE    -0.097772
# 324                FARTHER TWOS D SHARE DUNKS FG% RANK    -0.108849
# 325    CLOSE TWOS SHARE RANK FARTHER TWOS D SHARE RANK    -0.119084
# 326                              DUNKS FG% DUNKS SHARE    -0.125985
# 327             DUNKS FG% RANK CLOSE TWOS D SHARE RANK    -0.138483
# 328                DUNKS D SHARE CLOSE TWOS SHARE RANK    -0.152076
# 329                  THREES D SHARE DUNKS D SHARE RANK    -0.164397
# 330                                 DUNKS SHARE RANK^2    -0.176907
# 331                DUNKS D SHARE RANK THREES FG%D RANK    -0.191766
# 332                  FARTHER TWOS FG% THREES FG%D RANK    -0.204512
# 333                               DUNKS FG% DUNKS FG%D    -0.216491
# 334                         FARTHER TWOS FG% RANK SEED    -0.229335
# 335             DUNKS SHARE RANK CLOSE TWOS SHARE RANK    -0.246236
# 336          CLOSE TWOS FG% RANK CLOSE TWOS SHARE RANK    -0.253805
# 337                   DUNKS SHARE RANK THREES FG% RANK    -0.270443
# 338          FARTHER TWOS FG%D FARTHER TWOS SHARE RANK    -0.287811
# 339           FARTHER TWOS D SHARE THREES D SHARE RANK    -0.307666
# 340             CLOSE TWOS D SHARE THREES D SHARE RANK    -0.288258
# 341                                     CLOSE TWOS FG%    -0.303307
# 342                                DUNKS FG% RANK SEED    -0.322154
# 343                 FARTHER TWOS FG%D THREES FG%D RANK    -0.338094
# 344                             FARTHER TWOS FG%D SEED    -0.354228
# 345                DUNKS FG% FARTHER TWOS D SHARE RANK    -0.369812
# 346              THREES FG%D FARTHER TWOS D SHARE RANK    -0.393197
# 347            CLOSE TWOS FG% RANK THREES D SHARE RANK    -0.410309
# 348          FARTHER TWOS FG%D CLOSE TWOS D SHARE RANK    -0.425223
# 349     CLOSE TWOS D SHARE RANK FARTHER TWOS FG%D RANK    -0.443844
# 350          DUNKS FG%D RANK FARTHER TWOS D SHARE RANK    -0.466285
# 351               DUNKS FG%D FARTHER TWOS D SHARE RANK    -0.483851
# 352                 THREES SHARE FARTHER TWOS FG% RANK    -0.504892
# 353                              CLOSE TWOS FG% RANK^2    -0.515722
# 354                                         DUNKS FG%D    -0.526780
# 355                                   THREES FG%D SEED    -0.546018
# 356                              THREES FG%D RANK SEED    -0.554999
# 357                          DUNKS FG% THREES FG% RANK    -0.575355
# 358                                    DUNKS FG%D RANK    -0.591742
# 359                 THREES D SHARE CLOSE TWOS FG% RANK    -0.612100
# 360                          DUNKS FG%D CLOSE TWOS FG%    -0.629700
# 361                      CLOSE TWOS FG% THREES D SHARE    -0.647793
# 362             DUNKS D SHARE RANK CLOSE TWOS FG% RANK    -0.664338
# 363            FARTHER TWOS FG% RANK THREES SHARE RANK    -0.686332
# 364                 FARTHER TWOS FG%D DUNKS SHARE RANK    -0.713909
# 365               DUNKS D SHARE RANK THREES SHARE RANK    -0.745308
# 366                            CLOSE TWOS D SHARE SEED    -0.772364
# 367                      THREES FG%D THREES SHARE RANK    -0.805956
# 368                 CLOSE TWOS FG%D DUNKS D SHARE RANK    -0.827008
# 369               THREES D SHARE FARTHER TWOS FG% RANK    -0.850624
# 370                      THREES SHARE THREES FG%D RANK    -0.868520
# 371                           DUNKS FG% DUNKS FG% RANK    -0.888691
# 372                                   DUNKS FG% RANK^2    -0.854421
# 373              FARTHER TWOS SHARE DUNKS D SHARE RANK    -0.862691
# 374                      DUNKS FG%D DUNKS D SHARE RANK    -0.878032
# 375                CLOSE TWOS D SHARE THREES FG%D RANK    -0.902919
# 376                             FARTHER TWOS D SHARE^2    -0.927101
# 377                    DUNKS D SHARE FARTHER TWOS FG%D    -0.952585
# 378                            DUNKS D SHARE RANK SEED    -0.969095
# 379              FARTHER TWOS D SHARE THREES FG%D RANK    -1.004026
# 380         CLOSE TWOS D SHARE CLOSE TWOS D SHARE RANK    -1.024114
# 381                 CLOSE TWOS FG%D CLOSE TWOS D SHARE    -1.054582
# 382                DUNKS SHARE CLOSE TWOS D SHARE RANK    -1.079686
# 383                             THREES FG% THREES FG%D    -1.089223
# 384                                   CLOSE TWOS SHARE    -1.109082
# 385                       THREES SHARE THREES FG% RANK    -1.138390
# 386                     DUNKS D SHARE THREES FG%D RANK    -1.165753
# 387         CLOSE TWOS SHARE FARTHER TWOS D SHARE RANK    -1.206381
# 388                  DUNKS FG% CLOSE TWOS D SHARE RANK    -1.247628
# 389                     THREES FG% THREES D SHARE RANK    -1.269850
# 390              FARTHER TWOS FG%D CLOSE TWOS FG% RANK    -1.286412
# 391                                  THREES SHARE RANK    -1.318493
# 392           FARTHER TWOS FG% CLOSE TWOS D SHARE RANK    -1.337686
# 393              CLOSE TWOS SHARE RANK THREES FG% RANK    -1.344040
# 394                                       THREES SHARE    -1.364667
# 395                                     DUNKS FG% SEED    -1.397112
# 396                      CLOSE TWOS FG% DUNKS FG% RANK    -1.434981
# 397                 DUNKS FG% RANK THREES D SHARE RANK    -1.473042
# 398                  CLOSE TWOS FG% FARTHER TWOS SHARE    -1.517775
# 399                    DUNKS FG%D RANK THREES FG% RANK    -1.561724
# 400              CLOSE TWOS FG% FARTHER TWOS FG%D RANK    -1.585543
# 401                 CLOSE TWOS FG% CLOSE TWOS FG% RANK    -1.610251
# 402              FARTHER TWOS FG%D THREES D SHARE RANK    -1.640261
# 403                     THREES FG% CLOSE TWOS FG% RANK    -1.645700
# 404                           DUNKS FG% CLOSE TWOS FG%    -1.678326
# 405                         CLOSE TWOS FG%D THREES FG%    -1.734746
# 406                              FARTHER TWOS FG% SEED    -1.789072
# 407                   DUNKS D SHARE DUNKS D SHARE RANK    -1.832496
# 408                            FARTHER TWOS SHARE SEED    -1.889213
# 409                       DUNKS SHARE DUNKS SHARE RANK    -1.954191
# 410           CLOSE TWOS FG% RANK CLOSE TWOS FG%D RANK    -2.023587
# 411                        THREES FG% DUNKS SHARE RANK    -2.087254
# 412                       FARTHER TWOS FG% THREES FG%D    -2.155269
# 413               THREES D SHARE CLOSE TWOS SHARE RANK    -2.215095
# 414                        DUNKS FG% THREES SHARE RANK    -2.231362
# 415   FARTHER TWOS FG%D RANK FARTHER TWOS D SHARE RANK    -2.265844
# 416                    FARTHER TWOS FG% THREES D SHARE    -2.321410
# 417                  FARTHER TWOS D SHARE THREES SHARE    -2.322179
# 418                  DUNKS SHARE CLOSE TWOS SHARE RANK    -2.386089
# 419                                      DUNKS SHARE^2    -2.415874
# 420         FARTHER TWOS SHARE FARTHER TWOS SHARE RANK    -2.483365
# 421                   CLOSE TWOS FG% THREES SHARE RANK    -2.542590
# 422          FARTHER TWOS FG% RANK THREES D SHARE RANK    -2.587318
# 423                  FARTHER TWOS FG% DUNKS SHARE RANK    -2.603507
# 424                              DUNKS FG%D THREES FG%    -2.619921
# 425                      DUNKS D SHARE DUNKS FG%D RANK    -2.658321
# 426                        THREES FG% THREES FG%D RANK    -2.701182
# 427             THREES D SHARE CLOSE TWOS D SHARE RANK    -2.752471
# 428                               THREES FG% RANK SEED    -2.811349
# 429                DUNKS FG% RANK CLOSE TWOS FG%D RANK    -2.850373
# 430                          DUNKS FG% CLOSE TWOS FG%D    -2.837136
# 431               DUNKS D SHARE FARTHER TWOS FG%D RANK    -2.910781
# 432  FARTHER TWOS SHARE RANK FARTHER TWOS D SHARE RANK    -2.999886
# 433                 DUNKS FG%D CLOSE TWOS D SHARE RANK    -3.081797
# 434                                         THREES FG%    -3.168014
# 435                         DUNKS D SHARE THREES SHARE    -3.216685
# 436               FARTHER TWOS D SHARE DUNKS FG%D RANK    -3.242463
# 437                 CLOSE TWOS D SHARE DUNKS FG%D RANK    -3.336250
# 438                     DUNKS SHARE FARTHER TWOS SHARE    -3.358943
# 439           FARTHER TWOS SHARE RANK THREES FG%D RANK    -3.450032
# 440                CLOSE TWOS FG%D THREES D SHARE RANK    -3.553764
# 441                 DUNKS FG%D RANK DUNKS D SHARE RANK    -3.701188
# 442             CLOSE TWOS FG% CLOSE TWOS D SHARE RANK    -3.733692
# 443         FARTHER TWOS SHARE CLOSE TWOS D SHARE RANK    -3.803488
# 444    CLOSE TWOS D SHARE RANK FARTHER TWOS SHARE RANK    -3.918819
# 445              THREES SHARE RANK THREES D SHARE RANK    -3.957346
# 446           DUNKS FG% RANK FARTHER TWOS D SHARE RANK    -4.095108
# 447             CLOSE TWOS FG%D RANK THREES SHARE RANK    -4.215304
# 448                THREES FG% RANK THREES D SHARE RANK    -4.284656
# 449                  CLOSE TWOS FG%D THREES SHARE RANK    -4.308763
# 450                    DUNKS SHARE THREES D SHARE RANK    -4.374423
# 451               THREES SHARE CLOSE TWOS D SHARE RANK    -4.395191
# 452                      DUNKS SHARE FARTHER TWOS FG%D    -4.432314
# 453                   THREES FG% CLOSE TWOS SHARE RANK    -4.582390
# 454                 THREES FG% FARTHER TWOS SHARE RANK    -4.607067
# 455                   CLOSE TWOS SHARE THREES FG% RANK    -4.603342
# 456            DUNKS D SHARE RANK CLOSE TWOS FG%D RANK    -4.733738
# 457               DUNKS FG% RANK FARTHER TWOS FG% RANK    -4.923019
# 458                    FARTHER TWOS FG% DUNKS FG% RANK    -4.911678
# 459         FARTHER TWOS D SHARE FARTHER TWOS FG% RANK    -4.978505
# 460             CLOSE TWOS FG% FARTHER TWOS SHARE RANK    -5.244554
# 461                 FARTHER TWOS SHARE THREES FG% RANK    -5.451250
# 462     FARTHER TWOS D SHARE FARTHER TWOS D SHARE RANK    -5.576558
# 463                         DUNKS SHARE DUNKS FG% RANK    -5.685275
# 464                     THREES D SHARE THREES FG% RANK    -5.916792
# 465               FARTHER TWOS D SHARE THREES FG% RANK    -6.278601
# 466                    CLOSE TWOS FG% CLOSE TWOS SHARE    -6.592422
# 467            CLOSE TWOS FG%D CLOSE TWOS D SHARE RANK    -6.898228
# 468                                   DUNKS SHARE RANK    -7.258376
# 469                        DUNKS FG%D CLOSE TWOS SHARE    -7.598650
# 470                                    CLOSE TWOS FG%D    -7.905446
# 471                   DUNKS SHARE CLOSE TWOS FG%D RANK    -8.461676
# 472      FARTHER TWOS D SHARE RANK THREES D SHARE RANK    -8.653725
# 473                        DUNKS SHARE CLOSE TWOS FG%D    -8.642155
# 474                      DUNKS SHARE THREES SHARE RANK    -9.048392
# 475           FARTHER TWOS FG%D RANK THREES SHARE RANK    -9.483568
# 476                      FARTHER TWOS SHARE THREES FG%    -9.777032
# 477          CLOSE TWOS FG% RANK FARTHER TWOS FG% RANK   -10.293746
# 478               FARTHER TWOS FG% CLOSE TWOS FG% RANK   -10.728739
# 479                                          DUNKS FG%   -11.317587
# 480               CLOSE TWOS FG% FARTHER TWOS FG% RANK   -12.146850
# 481                         DUNKS FG% DUNKS SHARE RANK   -12.859414
# 482                                     THREES SHARE^2   -14.103109
# 483                CLOSE TWOS FG% CLOSE TWOS FG%D RANK   -14.593196
# 484                                       THREES FG%^2   -15.799076
# 485                            THREES FG% THREES SHARE   -16.582752
# 486                       THREES FG%D DUNKS SHARE RANK   -17.178164
# 487                    DUNKS D SHARE THREES SHARE RANK   -17.159038
# 488                            DUNKS SHARE THREES FG%D   -17.212341
# 489                   FARTHER TWOS FG% DUNKS FG%D RANK   -17.519249
# 490              THREES D SHARE FARTHER TWOS FG%D RANK   -18.603856
# 491                    FARTHER TWOS SHARE THREES SHARE   -20.413065
# 492                    CLOSE TWOS SHARE THREES D SHARE   -23.042703
# 493                                FARTHER TWOS FG%D^2   -25.339634
# 494                      CLOSE TWOS SHARE THREES SHARE   -26.110429
# 495                 CLOSE TWOS FG%D FARTHER TWOS SHARE   -28.690825
# 496                            DUNKS FG%D THREES SHARE   -27.002532
# 497                    DUNKS FG% FARTHER TWOS FG% RANK   -29.114747
# 498         FARTHER TWOS FG%D RANK THREES D SHARE RANK   -30.107446
# 499                  THREES FG%D CLOSE TWOS SHARE RANK   -34.805340
# 500           FARTHER TWOS FG%D FARTHER TWOS FG%D RANK   -34.725527
# 501                   DUNKS SHARE FARTHER TWOS D SHARE   -38.209319
# 502       FARTHER TWOS D SHARE FARTHER TWOS SHARE RANK   -47.362175
# 503                       DUNKS FG%D THREES SHARE RANK   -55.821173
# 504          CLOSE TWOS D SHARE RANK THREES SHARE RANK   -66.831309
# 505                   THREES SHARE THREES D SHARE RANK   -81.833616
# 506                   DUNKS FG%D CLOSE TWOS SHARE RANK  -113.133131
# 507                          FARTHER TWOS D SHARE SEED  -141.087199
# 508                    CLOSE TWOS FG% DUNKS SHARE RANK  -175.229292
# 509                  DUNKS D SHARE THREES D SHARE RANK  -346.147297
# 510                CLOSE TWOS SHARE CLOSE TWOS D SHARE  -842.412008
# 511                        CLOSE TWOS FG% THREES SHARE -2124.179861
# 512         DUNKS D SHARE RANK FARTHER TWOS SHARE RANK  -657.827982
# 513                       THREES SHARE DUNKS FG%D RANK  -432.919514
# 514           FARTHER TWOS D SHARE CLOSE TWOS FG% RANK  -302.708575
# 515           CLOSE TWOS SHARE FARTHER TWOS SHARE RANK  -233.461907
# 516                     DUNKS SHARE DUNKS D SHARE RANK  -181.280299
# 517                     DUNKS SHARE CLOSE TWOS D SHARE  -166.584158
# 518               FARTHER TWOS SHARE FARTHER TWOS FG%D  -140.790351
# 519            CLOSE TWOS D SHARE CLOSE TWOS FG%D RANK  -129.936060
# 520                 FARTHER TWOS FG% THREES SHARE RANK  -121.053963
# 521                         DUNKS FG% FARTHER TWOS FG%  -116.401454
# 522       CLOSE TWOS SHARE RANK FARTHER TWOS FG%D RANK  -108.744284
# 523                  CLOSE TWOS D SHARE DUNKS FG% RANK  -105.688276
# 524           CLOSE TWOS D SHARE CLOSE TWOS SHARE RANK  -104.036275
# 525                   CLOSE TWOS SHARE CLOSE TWOS FG%D  -101.642855
# 526                 FARTHER TWOS SHARE DUNKS FG%D RANK  -102.347312
# 527                       DUNKS SHARE CLOSE TWOS SHARE  -102.961710
# 528              FARTHER TWOS FG% FARTHER TWOS D SHARE  -104.762710
# 529           CLOSE TWOS FG%D RANK THREES D SHARE RANK  -105.639366
# 530                CLOSE TWOS SHARE FARTHER TWOS SHARE  -109.127395
# 531               CLOSE TWOS D SHARE THREES SHARE RANK  -111.124788
# 532                        FARTHER TWOS D SHARE RANK^2  -109.701974
# 533                          DUNKS D SHARE THREES FG%D  -106.587645
# 534            FARTHER TWOS SHARE FARTHER TWOS D SHARE  -103.852212
# 535                  CLOSE TWOS FG% CLOSE TWOS D SHARE   -97.590530
# 536             FARTHER TWOS FG% CLOSE TWOS SHARE RANK   -87.043763
# 537      CLOSE TWOS FG% RANK FARTHER TWOS D SHARE RANK   -72.255114
# 538                THREES D SHARE CLOSE TWOS FG%D RANK   -65.750708
# 539             THREES D SHARE FARTHER TWOS SHARE RANK   -60.788938
# 540                DUNKS SHARE FARTHER TWOS SHARE RANK   -57.022856
# 541                          CLOSE TWOS FG%D RANK SEED   -54.144707
# 542           FARTHER TWOS SHARE CLOSE TWOS SHARE RANK   -50.553642
# 543      CLOSE TWOS SHARE RANK CLOSE TWOS D SHARE RANK   -45.641883
# 544                    CLOSE TWOS FG% FARTHER TWOS FG%   -43.898192
# 545          FARTHER TWOS D SHARE CLOSE TWOS FG%D RANK   -42.373268
# 546             CLOSE TWOS D SHARE CLOSE TWOS FG% RANK   -41.236405
# 547                         DUNKS FG%D DUNKS FG%D RANK   -40.055188
# 548         CLOSE TWOS D SHARE FARTHER TWOS SHARE RANK   -39.117481
# 549                              FARTHER TWOS FG% RANK   -37.782342
# 550       CLOSE TWOS D SHARE FARTHER TWOS D SHARE RANK   -37.198677
# 551          CLOSE TWOS D SHARE FARTHER TWOS FG%D RANK   -36.768463
# 552                         THREES FG%D THREES D SHARE   -36.391102
# 553                                 CLOSE TWOS SHARE^2   -35.835908
# 554        FARTHER TWOS SHARE RANK THREES D SHARE RANK   -35.306792
# 555             FARTHER TWOS SHARE THREES D SHARE RANK   -35.051066
# 556       CLOSE TWOS FG%D RANK CLOSE TWOS D SHARE RANK   -34.956001
# 557                   CLOSE TWOS FG%D THREES FG%D RANK   -34.729902
# 558        CLOSE TWOS SHARE RANK FARTHER TWOS FG% RANK   -34.373390
# 559        CLOSE TWOS FG% RANK CLOSE TWOS D SHARE RANK   -33.139092
# 560       FARTHER TWOS D SHARE CLOSE TWOS D SHARE RANK   -32.783208
# 561                     CLOSE TWOS D SHARE THREES FG%D   -32.612036
# 562             DUNKS SHARE RANK FARTHER TWOS FG% RANK   -32.611825
# 563              DUNKS FG%D RANK FARTHER TWOS FG% RANK   -31.838889
# 564                FARTHER TWOS FG% FARTHER TWOS SHARE   -31.175743
# 565                      FARTHER TWOS FG% THREES SHARE   -31.243974
# 566                         DUNKS SHARE CLOSE TWOS FG%   -31.293460
# 567                   THREES D SHARE THREES SHARE RANK   -31.365595
# 568                               FARTHER TWOS SHARE^2   -31.415836
# 569                               CLOSE TWOS D SHARE^2   -31.340940
# 570                FARTHER TWOS D SHARE THREES D SHARE   -30.944033
# 571            CLOSE TWOS D SHARE FARTHER TWOS D SHARE   -30.955521
# 572                   CLOSE TWOS FG% FARTHER TWOS FG%D   -31.009973
# 573                DUNKS SHARE RANK DUNKS D SHARE RANK   -30.583109
# 574              CLOSE TWOS D SHARE FARTHER TWOS SHARE   -30.477576
# 575                  FARTHER TWOS SHARE THREES D SHARE   -30.063690
# 576               THREES SHARE FARTHER TWOS SHARE RANK   -30.011054
# 577                           FARTHER TWOS FG%D RANK^2   -30.046307
# 578              CLOSE TWOS FG%D RANK THREES FG%D RANK   -30.072935
# 579             CLOSE TWOS SHARE CLOSE TWOS SHARE RANK   -29.987457
# 580                    CLOSE TWOS D SHARE THREES SHARE   -30.135784
# 581                        THREES SHARE THREES D SHARE   -30.273769
# 582                                   THREES D SHARE^2   -30.577665
# 583                         THREES FG% THREES FG% RANK   -30.993289
# 584                     CLOSE TWOS FG%D THREES D SHARE   -31.088897
# 585                     THREES FG%D DUNKS D SHARE RANK   -30.620530
# 586               CLOSE TWOS FG%D FARTHER TWOS D SHARE   -30.558077
# 587         FARTHER TWOS D SHARE RANK THREES FG%D RANK   -30.828336
# 588                     DUNKS FG%D CLOSE TWOS FG% RANK   -31.130610
# 589                    THREES FG%D THREES D SHARE RANK   -31.565557
# 590               CLOSE TWOS FG%D RANK THREES FG% RANK   -32.060478
# 591                  DUNKS D SHARE CLOSE TWOS FG% RANK   -32.586725
# 592                   FARTHER TWOS FG%D THREES D SHARE   -33.135146
# 593               CLOSE TWOS D SHARE FARTHER TWOS FG%D   -33.375835
# 594           FARTHER TWOS FG% FARTHER TWOS SHARE RANK   -33.992582

# %%
ax1 = results.plot.line(x='feature added',y='valid R2')

# %%
model_opt
# Out:
# ['bias',
#  'SEED',
#  'CLOSE TWOS FG% SEED',
#  'CLOSE TWOS FG% RANK',
#  'SEED^2',
#  'DUNKS FG%D THREES D SHARE RANK',
#  'THREES SHARE DUNKS FG% RANK',
#  'DUNKS SHARE FARTHER TWOS FG%',
#  'DUNKS FG% THREES FG%D',
#  'CLOSE TWOS D SHARE THREES D SHARE',
#  'DUNKS SHARE RANK THREES SHARE RANK',
#  'CLOSE TWOS FG%D RANK^2',
#  'DUNKS FG%D CLOSE TWOS D SHARE',
#  'CLOSE TWOS SHARE DUNKS FG%D RANK',
#  'CLOSE TWOS FG%D RANK FARTHER TWOS D SHARE RANK',
#  'THREES FG%D RANK',
#  'DUNKS SHARE THREES FG%D RANK',
#  'THREES FG% RANK THREES SHARE RANK',
#  'CLOSE TWOS SHARE RANK SEED',
#  'DUNKS D SHARE CLOSE TWOS SHARE',
#  'DUNKS D SHARE CLOSE TWOS FG%',
#  'DUNKS D SHARE CLOSE TWOS D SHARE RANK',
#  'DUNKS FG% CLOSE TWOS SHARE',
#  'FARTHER TWOS FG%D THREES FG%',
#  'DUNKS FG% THREES FG%',
#  'THREES FG% DUNKS FG% RANK',
#  'DUNKS FG% THREES SHARE',
#  'CLOSE TWOS FG% DUNKS D SHARE RANK',
#  'THREES FG% RANK THREES FG%D RANK',
#  'DUNKS D SHARE RANK THREES FG% RANK',
#  'THREES SHARE SEED',
#  'FARTHER TWOS SHARE RANK SEED',
#  'THREES FG%D^2',
#  'DUNKS SHARE RANK FARTHER TWOS FG%D RANK',
#  'CLOSE TWOS FG%D RANK FARTHER TWOS FG%D RANK',
#  'CLOSE TWOS FG%D FARTHER TWOS FG%D RANK',
#  'DUNKS FG%D RANK CLOSE TWOS FG% RANK',
#  'CLOSE TWOS FG%D CLOSE TWOS FG% RANK',
#  'FARTHER TWOS SHARE RANK',
#  'DUNKS FG%D DUNKS SHARE RANK',
#  'CLOSE TWOS SHARE THREES D SHARE RANK',
#  'FARTHER TWOS FG% THREES D SHARE RANK',
#  'THREES SHARE DUNKS SHARE RANK',
#  'FARTHER TWOS FG%D FARTHER TWOS D SHARE RANK',
#  'CLOSE TWOS D SHARE RANK FARTHER TWOS FG% RANK',
#  'FARTHER TWOS FG% RANK FARTHER TWOS D SHARE RANK',
#  'THREES D SHARE THREES D SHARE RANK',
#  'FARTHER TWOS FG% RANK FARTHER TWOS SHARE RANK',
#  'FARTHER TWOS FG% THREES FG% RANK',
#  'CLOSE TWOS SHARE FARTHER TWOS FG%D RANK',
#  'THREES FG%D FARTHER TWOS FG% RANK',
#  'DUNKS SHARE THREES FG%',
#  'THREES SHARE RANK SEED',
#  'DUNKS FG% RANK CLOSE TWOS SHARE RANK',
#  'CLOSE TWOS FG% RANK SEED',
#  'THREES FG%D THREES FG%D RANK',
#  'CLOSE TWOS FG% FARTHER TWOS D SHARE RANK',
#  'THREES FG%D DUNKS FG% RANK',
#  'THREES FG% THREES SHARE RANK',
#  'THREES D SHARE THREES FG%D RANK',
#  'DUNKS D SHARE THREES FG%',
#  'DUNKS SHARE DUNKS D SHARE',
#  'DUNKS SHARE RANK CLOSE TWOS FG%D RANK',
#  'DUNKS FG% FARTHER TWOS SHARE',
#  'DUNKS D SHARE',
#  'FARTHER TWOS D SHARE',
#  'FARTHER TWOS FG%D',
#  'DUNKS FG%D RANK SEED',
#  'DUNKS FG%D CLOSE TWOS FG%D RANK',
#  'DUNKS FG%D CLOSE TWOS FG%D',
#  'FARTHER TWOS FG% FARTHER TWOS FG%D RANK',
#  'THREES D SHARE RANK^2',
#  'FARTHER TWOS D SHARE RANK SEED',
#  'DUNKS FG% THREES FG%D RANK',
#  'DUNKS FG%D RANK CLOSE TWOS SHARE RANK',
#  'DUNKS FG%D RANK CLOSE TWOS D SHARE RANK',
#  'DUNKS FG%D RANK FARTHER TWOS FG%D RANK',
#  'DUNKS FG%^2',
#  'DUNKS FG% CLOSE TWOS FG% RANK',
#  'FARTHER TWOS FG%D RANK THREES FG% RANK',
#  'CLOSE TWOS FG%D THREES FG% RANK',
#  'DUNKS D SHARE CLOSE TWOS D SHARE',
#  'FARTHER TWOS FG%D RANK SEED',
#  'CLOSE TWOS FG%D CLOSE TWOS SHARE RANK',
#  'CLOSE TWOS FG% CLOSE TWOS SHARE RANK',
#  'FARTHER TWOS SHARE DUNKS FG% RANK',
#  'FARTHER TWOS FG% RANK FARTHER TWOS FG%D RANK',
#  'FARTHER TWOS FG%D FARTHER TWOS D SHARE',
#  'CLOSE TWOS SHARE RANK^2',
#  'THREES FG%D',
#  'THREES FG% DUNKS D SHARE RANK',
#  'DUNKS D SHARE THREES FG% RANK',
#  'THREES D SHARE DUNKS FG%D RANK',
#  'DUNKS D SHARE RANK^2',
#  'FARTHER TWOS FG% THREES FG%',
#  'DUNKS D SHARE RANK CLOSE TWOS SHARE RANK',
#  'DUNKS SHARE',
#  'CLOSE TWOS SHARE THREES FG%D',
#  'FARTHER TWOS FG% RANK THREES FG% RANK',
#  'CLOSE TWOS FG%D DUNKS FG% RANK',
#  'DUNKS FG% DUNKS FG%D RANK',
#  'DUNKS SHARE RANK DUNKS FG%D RANK',
#  'DUNKS FG% CLOSE TWOS SHARE RANK',
#  'THREES FG% FARTHER TWOS FG% RANK',
#  'CLOSE TWOS SHARE THREES FG%',
#  'CLOSE TWOS D SHARE THREES FG%',
#  'DUNKS FG% RANK CLOSE TWOS FG% RANK',
#  'CLOSE TWOS FG% FARTHER TWOS D SHARE',
#  'THREES FG% FARTHER TWOS D SHARE RANK',
#  'DUNKS FG%D FARTHER TWOS SHARE RANK',
#  'CLOSE TWOS FG%D THREES FG%D']

# %%
Xe_train_opt = Xe_train[model_opt]
lr.fit(Xe_train_opt, y_train)
train_R2 = lr.score(Xe_train_opt, y_train)
train_R2
# Out:
# 0.5282927129162673

# %%
Xe_test_opt = Xe_test[model_opt]
test_R2 = lr.score(Xe_test_opt, y_test)
test_R2
# Out:
# -0.048686564421269285

# %%
coeffs = pd.Series(lr.coef_, Xe_train_opt.columns)
coeffs.sort_values()
# Out:
# DUNKS D SHARE THREES FG% RANK        -0.906295
# DUNKS D SHARE THREES FG%             -0.872572
# SEED                                 -0.598470
# DUNKS FG% THREES FG%                 -0.573365
# THREES FG% DUNKS FG% RANK            -0.507490
#                                         ...
# THREES FG% DUNKS D SHARE RANK         1.071842
# DUNKS D SHARE RANK THREES FG% RANK    1.213075
# DUNKS FG% CLOSE TWOS SHARE            6.914397
# DUNKS FG% THREES SHARE                8.398903
# DUNKS FG% FARTHER TWOS SHARE          9.078854
# Length: 111, dtype: float64

# %%
def PolyFeatures(X,degree,interaction_only=False):
    poly = PolynomialFeatures(degree,interaction_only=interaction_only)
    if X.ndim == 1:
        Xe = poly.fit_transform(X.values.reshape(-1,1))
        cols = poly.get_feature_names_out([X.name])
    else:
        Xe = poly.fit_transform(X)
        cols = poly.get_feature_names_out(X.columns)
    Xe = pd.DataFrame(Xe,columns=cols)
    print('X shape =',X.shape)
    print('X (engineered) shape =',Xe.shape)
    return Xe

# %%
Xe_train = PolyFeatures(X_train, degree=2)
Xe_test = PolyFeatures(X_test, degree=2)
# Out:
# X shape = (640, 33)
# X (engineered) shape = (640, 595)
# X shape = (64, 33)
# X (engineered) shape = (64, 595)

# %%
grid = {'alpha':[0.0001,0.01,0.1,1,10,100,1000,10000,100000]} # Use a log (base 10) scale to iterate over hyperparameter values
ridge = Ridge()
ridgeCV = GridSearchCV(ridge,param_grid=grid,return_train_score=True) # Optimize alpha
ridgeCV.fit(Xe_train,y_train) # Fit to training set

print()
print('best alpha =',ridgeCV.best_params_, '  valid R2 =',ridgeCV.best_score_.round(3))

results = pd.DataFrame()
results['alpha'] = np.log10(grid['alpha']) # Plot on a log base 10 grid, x-axis is the exponent
results['train R2'] = ridgeCV.cv_results_['mean_train_score']
results['valid R2']  = ridgeCV.cv_results_['mean_test_score']
ax1 = results.plot.line(x='alpha',y='train R2')
results.plot.line(x='alpha',y='valid R2',ax=ax1)

ridge = ridgeCV.best_estimator_
coef = pd.Series(ridge.coef_,index=Xe_train.columns)
coef.sort_values()
# Out:
# best alpha = {'alpha': 1000}   valid R2 = 0.139
# SEED                       -0.176453
# CLOSE TWOS FG% RANK        -0.067396
# CLOSE TWOS FG% SEED        -0.052715
# THREES FG%D                -0.043085
# DUNKS SHARE RANK           -0.040773
#                               ...
# THREES FG%                  0.038593
# DUNKS SHARE                 0.043250
# SEED^2                      0.048624
# CLOSE TWOS FG% RANK SEED    0.051841
# CLOSE TWOS FG%              0.067647
# Length: 595, dtype: float64

# %%
# regularize
grid = {'alpha':[0.0001,0.01,0.1,1,10,100,1000,10000,100000]}
lasso = Lasso()
lassoCV = GridSearchCV(lasso,param_grid=grid,return_train_score=True)
lassoCV.fit(Xe_train,y_train)
print()
print('best alpha =',lassoCV.best_params_, '  valid R2 =',lassoCV.best_score_.round(3))

results = pd.DataFrame()
results['alpha'] = np.log10(grid['alpha'])
results['train R2'] = lassoCV.cv_results_['mean_train_score']
results['valid R2']  = lassoCV.cv_results_['mean_test_score']
ax1 = results.plot.line(x='alpha',y='train R2')
results.plot.line(x='alpha',y='valid R2',ax=ax1)

lasso = lassoCV.best_estimator_
coef = pd.Series(lasso.coef_,index=Xe_train.columns)
coef.sort_values()
# Out:
# C:\Users\ranadeva\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.443e+01, tolerance: 9.199e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\ranadeva\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.566e+01, tolerance: 9.199e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\ranadeva\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.399e+01, tolerance: 9.199e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\ranadeva\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.842e+01, tolerance: 9.199e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\ranadeva\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.541e+01, tolerance: 9.199e-02
#   model = cd_fast.enet_coordinate_descent(
# best alpha = {'alpha': 0.1}   valid R2 = 0.309
# SEED                                     -0.574315
# CLOSE TWOS FG% SEED                      -0.117912
# THREES FG%D                              -0.017714
# CLOSE TWOS D SHARE^2                     -0.014437
# DUNKS FG%D THREES D SHARE RANK           -0.007957
#                                             ...
# CLOSE TWOS SHARE CLOSE TWOS SHARE RANK    0.000000
# DUNKS SHARE^2                             0.000281
# DUNKS FG%D FARTHER TWOS D SHARE           0.003839
# SEED^2                                    0.070364
# CLOSE TWOS FG%                            0.088550
# Length: 595, dtype: float64

# %%
ridge = ridgeCV.best_estimator_
lasso = lassoCV.best_estimator_
coef = pd.DataFrame()
coef['Ridge'] = ridge.coef_
coef['Lasso'] = lasso.coef_
coef.plot.box()
plt.ylim(-0.1,0.1)
# Out:
# (-0.1, 0.1)
