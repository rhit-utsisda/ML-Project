# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.model_selection import cross_validate, train_test_split
import graphviz

# %%
df = pd.read_csv('ShootingSplits_HeatCheckTour.csv')
df
# Out:
#      Unnamed: 0  YEAR  TEAM NO  TEAM ID              TEAM CONF  DUNKS FG%  \
# 0             0  2024     1079        2             Akron  MAC       97.2
# 1             1  2024     1078        3           Alabama  SEC       81.9
# 2             2  2024     1077        8           Arizona  P12       91.2
# 3             3  2024     1076       12            Auburn  SEC       87.7
# 4             4  2024     1075       14            Baylor  B12       89.2
# ..          ...   ...      ...      ...               ...  ...        ...
# 699         699  2013      336      226               VCU  A10       88.0
# 700         700  2013      335      228         Villanova   BE       74.6
# 701         701  2013      334      236  Western Kentucky   SB       88.2
# 702         702  2013      333      238       Wichita St.  MVC       86.8
# 703         703  2013      332      240         Wisconsin  B10       86.7
#
#      DUNKS SHARE  DUNKS FG%D  DUNKS D SHARE  ...  ROUND  POWER  PATH  DRAW  \
# 0            6.8        90.6            5.6  ...     64   54.3  79.8   NaN
# 1            9.5        89.2            7.3  ...      4   77.3  66.4   NaN
# 2           11.9        89.3            5.9  ...     16   86.2  64.6   NaN
# 3           13.2        87.1            4.7  ...     64   81.8  67.0   NaN
# 4           11.6        91.8            7.2  ...     32   80.6  65.5   NaN
# ..           ...         ...            ...  ...    ...    ...   ...   ...
# 699          5.2        88.1            4.8  ...     32   70.8  73.3 -1.58
# 700          6.1        85.5            4.9  ...     64   60.5  78.4 -1.20
# 701          4.2        94.6            4.3  ...     64   50.0  86.1  0.12
# 702          4.9        89.5            3.0  ...      4   68.7  81.1 -2.03
# 703          6.4        80.4            3.6  ...     64   78.6  70.9 -0.42
#
#      WINS  POOL VALUE  POOL S-RANK  NCAA S-RANK  VAL Z-SCORE  POWER-PATH
# 0       0         2.0           54           54          NaN       -25.5
# 1       4        39.0           13           16          NaN        10.9
# 2       2        91.8            2            6          NaN        21.6
# 3       0        49.6            9           15          NaN        14.8
# 4       1        51.5            8            9          NaN        15.1
# ..    ...         ...          ...          ...          ...         ...
# 699     1         7.8           38           20       -1.170        -2.5
# 700     0         3.0           52           38       -1.227       -17.9
# 701     0         0.9           62           61        0.311       -36.1
# 702     4         5.7           45           35       -0.553       -12.4
# 703     0        30.5           13           19        0.533         7.7
#
# [704 rows x 49 columns]

# %%
df = df.dropna(axis=1)
df_train = df[df['YEAR'] != 2024]
df_test = df[df['YEAR'] == 2024]

# %%
X_train = df_train.drop(['Unnamed: 0','YEAR','TEAM NO','TEAM ID','TEAM','CONF','WINS','ROUND'],axis=1)
X_test = df_test.drop(['Unnamed: 0','YEAR','TEAM NO','TEAM ID','TEAM','CONF','WINS','ROUND'],axis=1)
y_train = df_train.WINS
y_test = df_test.WINS

# %%
X_train = (X_train - X_train.mean())/X_train.std()
X_test = (X_test - X_test.mean())/X_test.std()

# %%
dtree = DecisionTreeClassifier(max_depth=2)
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
dtree.score(X_train,y_train)
# Out:
# 0.5453125

# %%
dtree_string = export_text(dtree,feature_names = list(X_train.columns),decimals = 1, spacing = 5)
print(dtree_string)
# Out:
# |----- POWER-PATH <= -0.2
# |     |----- POWER-PATH <= -0.9
# |     |     |----- class: 0
# |     |----- POWER-PATH >  -0.9
# |     |     |----- class: 0
# |----- POWER-PATH >  -0.2
# |     |----- POWER-PATH <= 0.7
# |     |     |----- class: 0
# |     |----- POWER-PATH >  0.7
# |     |     |----- class: 2

# %%
cv_results = cross_validate(dtree,X_train,y_train)
acc_valid = cv_results['test_score'].mean()
print('validation accuracy rate',acc_valid)
# Out:
# validation accuracy rate 0.5234375

# %%
dtree.score(X_test,y_test)
# Out:
# 0.578125
